# %% [markdown]
# #1. Scriping

# %% [markdown]
# ##1. Import Libary yang di gunakan

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ##2. Mengambil konten dari URL

# %%
def get_content(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.content, 'html.parser')
    return soup

# %% [markdown]
# ##3. Scraping satu halaman

# %%
def scrape_page(page_num):
    url = f"https://indeks.kompas.com/?page={page_num}"
    soup = get_content(url)

    articles = soup.find_all('div', class_='articleItem')

    print(f"Page {page_num}: Found {len(articles)} articles")

    data = []

    for article in articles:
        title = article.find('h2', class_='articleTitle').text.strip()
        category = article.find('div', class_='articlePost-subtitle').text.strip()
        date = article.find('div', class_='articlePost-date').text.strip()
        link = article.find('a')['href']

        # Mendapatkan isi berita
        article_soup = get_content(link)
        content = article_soup.find('div', class_='read__content').text.strip()

        data.append({
            'Title': title,
            'Category': category,
            'Date': date,
            'Content': content
        })

    return data

# %% [markdown]
# ##4. Scraping beberapa halaman

# %%
def scrape_kompas(pages=10):
    all_data = []
    for page_num in range(1, pages + 1):
        data = scrape_page(page_num)
        all_data.extend(data)
    return all_data

# %% [markdown]
# ##5. Menyimpan hasil scraping ke dalam file CSV

# %%
def save_to_csv(data, filename='kompas_scraping_results.csv'):
    df = pd.DataFrame(data)
    df.to_csv(filename, index=False)
    print(f"\n Data saved to {filename}")

# %% [markdown]
# ##6. Scrape 10 halaman dari kompas.com

# %%
scraped_data = scrape_kompas(pages=30)

df = pd.DataFrame(scraped_data)
print(df.head(5))

save_to_csv(scraped_data)
# Out:
# Page 1: Found 15 articles
# Page 2: Found 15 articles
# Page 3: Found 15 articles
# Page 4: Found 15 articles
# Page 5: Found 15 articles
# Page 6: Found 15 articles
# Page 7: Found 15 articles
# Page 8: Found 15 articles
# Page 9: Found 15 articles
# Page 10: Found 15 articles
# Page 11: Found 15 articles
# Page 12: Found 15 articles
# Page 13: Found 15 articles
# Page 14: Found 15 articles
# Page 15: Found 15 articles
# Page 16: Found 15 articles
# Page 17: Found 15 articles
# Page 18: Found 15 articles
# Page 19: Found 15 articles
# Page 20: Found 15 articles
# Page 21: Found 15 articles
# Page 22: Found 15 articles
# Page 23: Found 15 articles
# Page 24: Found 15 articles
# Page 25: Found 15 articles
# Page 26: Found 15 articles
# Page 27: Found 15 articles
# Page 28: Found 15 articles
# Page 29: Found 15 articles
# Page 30: Found 15 articles
#                                                Title  Category        Date  \
# 0  Menikmati Indahnya Pohon Natal dari Botol Beka...  REGIONAL  24/12/2024
# 1  Polisi Selidiki Kasus Bocah Jatuh dari Lantai ...      NEWS  24/12/2024
# 2  Bocah Tewas Terjatuh dari Lantai 18 Apartemen ...      NEWS  24/12/2024
# 3  Perjalanan Sudarti Mengubah Hidup, dari Buruh ...     MONEY  24/12/2024
# 4  Video Viral Pengeroyokan di Jalur Alternatif P...  OTOMOTIF  24/12/2024
#
#                                              Content
# 0  LAMPUNG, KOMPAS.com - Sebuah pohon Natal yang ...
# 1  TANGERANG SELATAN, KOMPAS.com - Polisi tengah ...
# 2  TANGERANG SELATAN, KOMPAS.com – Seorang anak t...
# 3  KOMPAS.com - Cuaca terik di Kabupaten Rembang,...
# 4  JAKARTA, KOMPAS.com - Video viral di media sos...
#
#  Data saved to kompas_scraping_results.csv
